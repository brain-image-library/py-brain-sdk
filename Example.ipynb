# %%
import brainimagelibrary as brainzzz
import pandas as pd

# %%
bildid = 'ace-ace-ace'
inventory = brainzzz.inventory.get(bildid=bildid)

# %%
inventory
# Out:
# {'affiliation': 'Cold Spring Harbor Laboratory',
#  'award_number': '1-U19-MH114821-01',
#  'contributor_name': 'Z. Josh Huang',
#  'creation_date': 'Wed Dec  5 05:38:10 2018',
#  'dataset_uuid': '9c8ee879-91c0-5953-8716-9dc02cda3b0b',
#  'directory': '/bil/data/48/8f/488f0cbd3de76a4a/level_1/161007_KM_TcergAi14_male_processed',
#  'download_url': 'https://download.brainimagelibrary.org/48/8f/488f0cbd3de76a4a/level_1/161007_KM_TcergAi14_male_processed',
#  'file_types': {'images': 520},
#  'frequencies': {'.jp2': 520},
#  'manifest': [{'download_url': 'https://download.brainimagelibrary.org/48/8f/488f0cbd3de76a4a/level_1/161007_KM_TcergAi14_male_processed/stitchedImage_ch1/StitchedImage_Z151_L001_lossless.jp2',
#    'extension': '.jp2',
#    'filename': 'StitchedImage_Z151_L001_lossless.jp2',
#    'filetype': 'images',
#    'fullpath': '/bil/data/48/8f/488f0cbd3de76a4a/level_1/161007_KM_TcergAi14_male_processed/stitchedImage_ch1/StitchedImage_Z151_L001_lossless.jp2',
# ...
